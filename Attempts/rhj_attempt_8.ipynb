# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# When importing dataset, by sorting with MatchID, dataset is now timeseries dataset. Every feature is (home-away) and result is decided with score diff. We have total 50 feature differences.

# %%
data=pd.read_csv('Data/Dataset.csv').drop(['Unnamed: 0'],axis=1).sort_values(by=['MatchID'])
df_home=data.filter(regex='home').rename(columns=lambda x:x.replace('_home',''))
df_away=data.filter(regex='away').rename(columns=lambda x:x.replace('_away',''))
df_diff=df_home-df_away
cond=[(df_diff['Score']<0),(df_diff['Score']==0),(df_diff['Score']>0)]
val=['Away','Draw','Home']
df_diff['Result']=np.select(cond,val)
df_diff=df_diff.drop(columns=['Score'])
X=df_diff.iloc[:,:-1]
y=df_diff.iloc[:,-1:].values.ravel()

# %%
scaler = StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %% [markdown]
# ## Train,Test,Validation set split
# Split train,test,validation set into 0.8,0.1,0.1

# %%
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2)
X_test,X_val,y_test,y_val=train_test_split(X_test,y_test,test_size=0.5)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((2835, 50), (2835,), (354, 50), (354,), (355, 50), (355,))

# %% [markdown]
# ## Feature selection

# %%
forest=RandomForestClassifier()
forest.fit(X_train,y_train)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("{}. feature {} ({:.3f})".format(f + 1, X.columns[indices][f], importances[indices[f]]))

# Plot the impurity-based feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=45)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature Clean sheets (0.041)
# 2. feature Assists (0.037)
# 3. feature Big Chances Created (0.032)
# 4. feature Passes (0.031)
# 5. feature Goals (0.029)
# 6. feature Goals Conceded (0.025)
# 7. feature Blocked shots (0.025)
# 8. feature Goals with right foot (0.021)
# 9. feature Shots on target (0.021)
# 10. feature Shots (0.021)
# 11. feature Goals with left foot (0.021)
# 12. feature Clearances off line (0.020)
# 13. feature Catches (0.019)
# 14. feature Hit woodwork (0.019)
# 15. feature Own goals (0.019)
# 16. feature Big chances missed (0.019)
# 17. feature Errors leading to goal (0.019)
# 18. feature Offsides (0.019)
# 19. feature Freekicks scored (0.019)
# 20. feature Sweeper clearances (0.019)
# 21. feature Penalties scored (0.019)
# 22. feature Throw outs (0.019)
# 23. feature Red cards (0.018)
# 24. feature Accurate long balls (0.018)
# 25. feature Punches (0.018)
# 26. feature Last man tackles (0.018)
# 27. feature Goal Kicks (0.018)
# 28. feature Penalties Saved (0.018)
# 29. feature Through balls (0.018)
# 30. feature Aerial battles won (0.018)
# 31. feature Shooting accuracy % (0.018)
# 32. feature Aerial battles lost (0.018)
# 33. feature Successful 50/50s (0.018)
# 34. feature Tackle success % (0.018)
# 35. feature Passes per match (0.018)
# 36. feature Tackles (0.017)
# 37. feature Crosses (0.017)
# 38. feature High Claims (0.017)
# 39. feature Recoveries (0.017)
# 40. feature Headed goals (0.017)
# 41. feature Interceptions (0.017)
# 42. feature Goals per match (0.017)
# 43. feature Cross accuracy % (0.017)
# 44. feature Fouls (0.017)
# 45. feature Yellow cards (0.017)
# 46. feature Clearances (0.016)
# 47. feature Headed Clearance (0.016)
# 48. feature Saves (0.016)
# 49. feature Duels lost (0.016)
# 50. feature Duels won (0.014)

# %% [markdown]
# ## Logistic Regression

# %%
clf = LogisticRegression()
clf.max_iter=500
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
clf.score(X_test,y_test)
# Out:
# 0.519774011299435

# %%
clf.score(X_val,y_val)
# Out:
# 0.5492957746478874

# %% [markdown]
# ## SVM

# %%
clf = svm.SVC()
clf.fit(X_train,y_train)
# Out:
# SVC()

# %%
clf.score(X_test,y_test)
# Out:
# 0.536723163841808

# %%
clf.score(X_val,y_val)
# Out:
# 0.5154929577464789

# %% [markdown]
# ## SVM pairwise

# %%
clf=svm.LinearSVC()
clf.fit(X_train,y_train)
# Out:
# /Users/hokuma/miniconda/lib/python3.9/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC()

# %%
clf.score(X_test,y_test)
# Out:
# 0.5338983050847458

# %%
clf.score(X_val,y_val)
# Out:
# 0.5521126760563381

# %% [markdown]
# ## GridSearch to optimize hyperparameter

# %%
parameters = {'kernel':('linear', 'rbf'), 'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 'C':np.arange(1, 10,step=3)}
svc=svm.SVC()
clf = GridSearchCV(svc, parameters)
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': array([1, 4, 7]),
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ('linear', 'rbf')})

# %%
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.5499118165784832

# %%
clf.score(X_test,y_test)
# Out:
# 0.6129943502824858

# %%
clf.score(X_val,y_val)
# Out:
# 0.543661971830986
